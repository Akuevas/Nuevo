# %% [markdown]
# <a href="https://colab.research.google.com/github/Akuevas/Nuevo/blob/main/Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
print("Hola Mundo")
# Out:
# carpeta  file.py  prueba  prueba.py  sample_data
# Hola Mundo

# %% [markdown]
# #Inicio

# %% [markdown]
# #A
#
# Este es un bloque de prueba

# %%
# !mkdir carpeta
# Out:
# mkdir: cannot create directory ‘carpeta’: File exists

# %%
# !cd carpeta/
# !touch file.cpp
